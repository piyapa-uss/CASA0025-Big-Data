# %% [markdown]
# # Week 2 Lab
#
# **Datasets**:
#
# The following datasets are used in this lab.
#
# - [nyc_subway_stations.tsv](https://storage.googleapis.com/qm2/CASA0025/nyc_subway_stations.tsv)
# - [nyc_neighborhoods.tsv](https://storage.googleapis.com/qm2/CASA0025/nyc_neighborhoods.tsv)

# %%
# %pip install duckdb duckdb-engine jupysql
# Out:
# Requirement already satisfied: duckdb in /usr/local/lib/python3.12/dist-packages (1.3.2)
# Requirement already satisfied: duckdb-engine in /usr/local/lib/python3.12/dist-packages (0.17.0)
# Requirement already satisfied: jupysql in /usr/local/lib/python3.12/dist-packages (0.11.1)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from duckdb-engine) (25.0)
# Requirement already satisfied: sqlalchemy>=1.3.22 in /usr/local/lib/python3.12/dist-packages (from duckdb-engine) (2.0.45)
# Requirement already satisfied: prettytable>=3.12.0 in /usr/local/lib/python3.12/dist-packages (from jupysql) (3.17.0)
# Requirement already satisfied: sqlparse in /usr/local/lib/python3.12/dist-packages (from jupysql) (0.5.5)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from jupysql) (0.2.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from jupysql) (3.1.6)
# Requirement already satisfied: sqlglot>=11.3.7 in /usr/local/lib/python3.12/dist-packages (from jupysql) (25.20.2)
# Requirement already satisfied: jupysql-plugin>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from jupysql) (0.4.5)
# Requirement already satisfied: ploomber-core>=0.2.7 in /usr/local/lib/python3.12/dist-packages (from jupysql) (0.2.27)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from ploomber-core>=0.2.7->jupysql) (6.0.3)
# Requirement already satisfied: posthog>=3.0 in /usr/local/lib/python3.12/dist-packages (from ploomber-core>=0.2.7->jupysql) (7.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prettytable>=3.12.0->jupysql) (0.2.14)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.3.22->duckdb-engine) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.3.22->duckdb-engine) (4.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->jupysql) (3.0.3)
# Requirement already satisfied: requests<3.0,>=2.7 in /usr/local/lib/python3.12/dist-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.32.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in /usr/local/lib/python3.12/dist-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2026.1.4)

# %%
import duckdb

# %load_ext sql

# %%
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %% [markdown]
# ## Question 1: Creating Tables
#
# Create a database, then write a SQL query to create a table named `nyc_subway_stations` and load the data from the file `nyc_subway_stations.tsv` into it. Similarly, create a table named `nyc_neighborhoods` and load the data from the file `nyc_neighborhoods.tsv` into it.

# %%
# %sql duckdb:///:memory:

# %%
# %%sql
# SELECT * FROM duckdb_extensions();
# Out:
#       extension_name  loaded  installed  \
# 0       autocomplete   False      False
# 1                aws   False      False
# 2              azure   False      False
# 3     core_functions    True       True
# 4              delta   False      False
# 5           ducklake   False      False
# 6          encodings   False      False
# 7              excel   False      False
# 8                fts   False      False
# 9             httpfs   False       True
# 10           iceberg   False      False
# 11               icu    True       True
# 12              inet   False      False
# 13          jemalloc    True       True
# 14              json    True       True
# 15        motherduck   False      False
# 16     mysql_scanner   False      False
# 17           parquet    True       True
# 18  postgres_scanner   False      False
# 19           spatial   False      False
# 20    sqlite_scanner   False      False
# 21             tpcds   False      False
# 22              tpch   False      False
# 23                ui   False      False
# 24               vss   False      False
#
#                                          install_path  \
# 0
# 1
# 2
# 3                                          (BUILT-IN)
# 4
# 5
# 6
# 7
# 8
# 9   /root/.duckdb/extensions/v1.3.2/linux_amd64/ht...
# 10
# 11                                         (BUILT-IN)
# 12
# 13                                         (BUILT-IN)
# 14                                         (BUILT-IN)
# 15
# 16
# 17                                         (BUILT-IN)
# 18
# 19
# 20
# 21
# 22
# 23
# 24
#
#                                           description            aliases  \
# 0          Adds support for autocomplete in the shell                 []
# 1        Provides features that depend on the AWS SDK                 []
# 2   Adds a filesystem abstraction for Azure blob s...                 []
# 3                               Core function library                 []
# 4                         Adds support for Delta Lake                 []
# 5   Adds support for DuckLake, SQL as a Lakehouse ...                 []
# 6                      All unicode encodings to UTF-8                 []
# 7          Adds support for Excel-like format strings                 []
# 8           Adds support for Full-Text Search Indexes                 []
# 9   Adds support for reading and writing files ove...  [http, https, s3]
# 10                    Adds support for Apache Iceberg                 []
# 11  Adds support for time zones and collations usi...                 []
# 12  Adds support for IP-related data types and fun...                 []
# 13          Overwrites system allocator with JEMalloc                 []
# 14                   Adds support for JSON operations                 []
# 15     Enables motherduck integration with the system               [md]
# 16    Adds support for connecting to a MySQL database            [mysql]
# 17  Adds support for reading and writing parquet f...                 []
# 18  Adds support for connecting to a Postgres data...         [postgres]
# 19  Geospatial extension that adds support for wor...                 []
# 20  Adds support for reading and writing SQLite da...  [sqlite, sqlite3]
# 21      Adds TPC-DS data generation and query support                 []
# 22       Adds TPC-H data generation and query support                 []
# 23                           Adds local UI for DuckDB                 []
# 24  Adds indexing support to accelerate Vector Sim...                 []
#
#    extension_version       install_mode installed_from
# 0                         NOT_INSTALLED
# 1                         NOT_INSTALLED
# 2                         NOT_INSTALLED
# 3                     STATICALLY_LINKED
# 4                         NOT_INSTALLED
# 5                         NOT_INSTALLED
# 6                         NOT_INSTALLED
# 7                         NOT_INSTALLED
# 8                         NOT_INSTALLED
# 9            af7bcaf         REPOSITORY           core
# 10                        NOT_INSTALLED
# 11                    STATICALLY_LINKED
# 12                        NOT_INSTALLED
# 13                    STATICALLY_LINKED
# 14                    STATICALLY_LINKED
# 15                        NOT_INSTALLED
# 16                        NOT_INSTALLED
# 17                    STATICALLY_LINKED
# 18                        NOT_INSTALLED
# 19                        NOT_INSTALLED
# 20                        NOT_INSTALLED
# 21                        NOT_INSTALLED
# 22                        NOT_INSTALLED
# 23                        NOT_INSTALLED
# 24                        NOT_INSTALLED

# %%
# %%sql
# INSTALL httpfs;
# LOAD httpfs;
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# Read CSV from link data
# %%sql
SELECT * FROM 'https://storage.googleapis.com/qm2/CASA0025/nyc_subway_stations.tsv';
# Out:
#      OBJECTID     ID               NAME         ALT_NAME         CROSS_ST  \
# 0           1  376.0       Cortlandt St             None        Church St
# 1           2    2.0          Rector St             None             None
# 2           3    1.0        South Ferry             None             None
# 3           4  125.0           138th St  Grand Concourse  Grand Concourse
# 4           5  126.0           149th St  Grand Concourse  Grand Concourse
# ..        ...    ...                ...              ...              ...
# 486       487  909.0     JFK Terminal 8             None             None
# 487       488  903.0     Federal Circle       Rental Car             None
# 488       489  902.0  Long Term Parking             None             None
# 489       490  901.0       Howard Beach             None        159th Ave
# 490       491  900.0            Jamaica     Sutphin Blvd     Sutphin Blvd
#
#                                   LONG_NAME                             LABEL  \
# 0              Cortlandt St (R,W) Manhattan                Cortlandt St (R,W)
# 1                   Rector St (1) Manhattan                     Rector St (1)
# 2                 South Ferry (1) Manhattan                   South Ferry (1)
# 3    138th St / Grand Concourse (4,5) Bronx  138th St / Grand Concourse (4,5)
# 4      149th St / Grand Concourse (4) Bronx    149th St / Grand Concourse (4)
# ..                                      ...                               ...
# 486                  JFK Terminal 8, Queens                    JFK Terminal 8
# 487     Federal Circle / Rental Car, Queens       Federal Circle / Rental Car
# 488               Long Term Parking, Queens                 Long Term Parking
# 489                    Howard Beach, Queens                      Howard Beach
# 490          Jamaica / Sutphin Blvd, Queens            Jamaica / Sutphin Blvd
#
#        BOROUGH NGHBHD ROUTES TRANSFERS     COLOR  EXPRESS  CLOSED
# 0    Manhattan   None    R,W       R,W    YELLOW     None    <NA>
# 1    Manhattan   None      1         1       RED     None    <NA>
# 2    Manhattan   None      1         1       RED     None    <NA>
# 3        Bronx   None    4,5       4,5     GREEN     None    <NA>
# 4        Bronx   None      4     2,4,5     GREEN  express    <NA>
# ..         ...    ...    ...       ...       ...      ...     ...
# 486     Queens   None   None      None  AIR-BLUE     None    <NA>
# 487     Queens   None   None      None  AIR-BLUE     None    <NA>
# 488     Queens   None   None      None  AIR-BLUE     None    <NA>
# 489     Queens   None   None         A  AIR-BLUE     None    <NA>
# 490     Queens   None   None     E,J,Z  AIR-BLUE     None    <NA>
#
# [491 rows x 14 columns]

# %%
# Create table stations
# %%sql
CREATE TABLE nyc_subway_stations AS SELECT * FROM 'https://storage.googleapis.com/qm2/CASA0025/nyc_subway_stations.tsv';
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# Create table neighborhood
# %%sql
create table nyc_neighborhoods as select * from 'https://storage.googleapis.com/qm2/CASA0025/nyc_neighborhoods.tsv';
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# Display nyc_subway_stations table in database
# %%sql
from nyc_subway_stations;
# Out:
#      OBJECTID     ID               NAME         ALT_NAME         CROSS_ST  \
# 0           1  376.0       Cortlandt St             None        Church St
# 1           2    2.0          Rector St             None             None
# 2           3    1.0        South Ferry             None             None
# 3           4  125.0           138th St  Grand Concourse  Grand Concourse
# 4           5  126.0           149th St  Grand Concourse  Grand Concourse
# ..        ...    ...                ...              ...              ...
# 486       487  909.0     JFK Terminal 8             None             None
# 487       488  903.0     Federal Circle       Rental Car             None
# 488       489  902.0  Long Term Parking             None             None
# 489       490  901.0       Howard Beach             None        159th Ave
# 490       491  900.0            Jamaica     Sutphin Blvd     Sutphin Blvd
#
#                                   LONG_NAME                             LABEL  \
# 0              Cortlandt St (R,W) Manhattan                Cortlandt St (R,W)
# 1                   Rector St (1) Manhattan                     Rector St (1)
# 2                 South Ferry (1) Manhattan                   South Ferry (1)
# 3    138th St / Grand Concourse (4,5) Bronx  138th St / Grand Concourse (4,5)
# 4      149th St / Grand Concourse (4) Bronx    149th St / Grand Concourse (4)
# ..                                      ...                               ...
# 486                  JFK Terminal 8, Queens                    JFK Terminal 8
# 487     Federal Circle / Rental Car, Queens       Federal Circle / Rental Car
# 488               Long Term Parking, Queens                 Long Term Parking
# 489                    Howard Beach, Queens                      Howard Beach
# 490          Jamaica / Sutphin Blvd, Queens            Jamaica / Sutphin Blvd
#
#        BOROUGH NGHBHD ROUTES TRANSFERS     COLOR  EXPRESS  CLOSED
# 0    Manhattan   None    R,W       R,W    YELLOW     None    <NA>
# 1    Manhattan   None      1         1       RED     None    <NA>
# 2    Manhattan   None      1         1       RED     None    <NA>
# 3        Bronx   None    4,5       4,5     GREEN     None    <NA>
# 4        Bronx   None      4     2,4,5     GREEN  express    <NA>
# ..         ...    ...    ...       ...       ...      ...     ...
# 486     Queens   None   None      None  AIR-BLUE     None    <NA>
# 487     Queens   None   None      None  AIR-BLUE     None    <NA>
# 488     Queens   None   None      None  AIR-BLUE     None    <NA>
# 489     Queens   None   None         A  AIR-BLUE     None    <NA>
# 490     Queens   None   None     E,J,Z  AIR-BLUE     None    <NA>
#
# [491 rows x 14 columns]

# %%
# Display nyc_neighborhoods table in database
# %%sql
from nyc_neighborhoods;
# Out:
#           BORONAME                      NAME
# 0         Brooklyn               Bensonhurst
# 1        Manhattan              East Village
# 2        Manhattan              West Village
# 3        The Bronx              Throggs Neck
# 4        The Bronx  Wakefield-Williamsbridge
# ..             ...                       ...
# 124       Brooklyn                  Red Hook
# 125         Queens   Douglastown-Little Neck
# 126         Queens                Whitestone
# 127         Queens                  Steinway
# 128  Staten Island                  Rosebank
#
# [129 rows x 2 columns]

# %% [markdown]
# ## Question 2: Column Filtering
#
# Write a SQL query to display the `ID`, `NAME`, and `BOROUGH` of each subway station in the `nyc_subway_stations` dataset.

# %%
# Filtering by selection command to show 3 columns of ID, name and borough
# %%sql
select id, name, borough
from nyc_subway_stations;
# Out:
#         ID               NAME    BOROUGH
# 0    376.0       Cortlandt St  Manhattan
# 1      2.0          Rector St  Manhattan
# 2      1.0        South Ferry  Manhattan
# 3    125.0           138th St      Bronx
# 4    126.0           149th St      Bronx
# ..     ...                ...        ...
# 486  909.0     JFK Terminal 8     Queens
# 487  903.0     Federal Circle     Queens
# 488  902.0  Long Term Parking     Queens
# 489  901.0       Howard Beach     Queens
# 490  900.0            Jamaica     Queens
#
# [491 rows x 3 columns]

# %% [markdown]
# ## Question 3: Row Filtering
#
# Write a SQL query to find all subway stations in the `nyc_subway_stations` dataset that are located in the borough of Manhattan.

# %%
# Filtering by select stations only in borough of Manhattan
# %%sql
select *
from nyc_subway_stations
where borough = 'Manhattan';
# Out:
#      OBJECTID     ID                NAME     ALT_NAME          CROSS_ST  \
# 0           1  376.0        Cortlandt St         None         Church St
# 1           2    2.0           Rector St         None              None
# 2           3    1.0         South Ferry         None              None
# 3          25  296.0            W 4th St         None           6th Ave
# 4         242  121.0            103rd St         None     Lexington Ave
# ..        ...    ...                 ...          ...               ...
# 135       374   72.0             Wall St         None        William St
# 136       375  378.0        Whitehall St  South Ferry          Water St
# 137       383  491.0        Cortlandt St         None     West Broadway
# 138       480  492.0  World Trade Center  Chambers St         Church St
# 139       481   99.0            Times Sq      42nd St  7th Ave/Broadway
#
#                                           LONG_NAME  \
# 0                      Cortlandt St (R,W) Manhattan
# 1                           Rector St (1) Manhattan
# 2                         South Ferry (1) Manhattan
# 3                      W 4th St (B,D,F,V) Manhattan
# 4                            103rd St (6) Manhattan
# ..                                              ...
# 135                         Wall St (2,3) Manhattan
# 136      Whitehall St / South Ferry (R,W) Manhattan
# 137                      Cortlandt St (1) Manhattan
# 138  World Trade Center / Chambers St (E) Manhattan
# 139                      Times Sq (1,2,3) Manhattan
#
#                                     LABEL    BOROUGH NGHBHD   ROUTES  \
# 0                      Cortlandt St (R,W)  Manhattan   None      R,W
# 1                           Rector St (1)  Manhattan   None        1
# 2                         South Ferry (1)  Manhattan   None        1
# 3                      W 4th St (B,D,F,V)  Manhattan   None  B,D,F,V
# 4                            103rd St (6)  Manhattan   None        6
# ..                                    ...        ...    ...      ...
# 135                         Wall St (2,3)  Manhattan   None      2,3
# 136      Whitehall St / South Ferry (R,W)  Manhattan   None      R,W
# 137                      Cortlandt St (1)  Manhattan   None        1
# 138  World Trade Center / Chambers St (E)  Manhattan   None        E
# 139            Times Sq / 42nd St (1,2,3)  Manhattan   None    1,2,3
#
#                    TRANSFERS   COLOR  EXPRESS  CLOSED
# 0                        R,W  YELLOW     None    <NA>
# 1                          1     RED     None    <NA>
# 2                          1     RED     None    <NA>
# 3              A,B,C,D,E,F,V  ORANGE  express    <NA>
# 4                          6   GREEN     None    <NA>
# ..                       ...     ...      ...     ...
# 135                      2,3     RED  express    <NA>
# 136                      R,W  YELLOW     None    <NA>
# 137                        1  CLOSED     None    True
# 138                A,C,E,2,3    BLUE     None    <NA>
# 139  A,C,E,N,Q,R,S,W,1,2,3,7     RED  express    <NA>
#
# [140 rows x 14 columns]

# %%
# %%sql
# SELECT name
# FROM nyc_subway_stations
# WHERE borough = 'Manhattan';
# Out:
#                    NAME
# 0          Cortlandt St
# 1             Rector St
# 2           South Ferry
# 3              W 4th St
# 4              103rd St
# ..                  ...
# 135             Wall St
# 136        Whitehall St
# 137        Cortlandt St
# 138  World Trade Center
# 139            Times Sq
#
# [140 rows x 1 columns]

# %% [markdown]
# ## Question 4: Sorting Results
#
# Write a SQL query to list the subway stations in the `nyc_subway_stations` dataset in alphabetical order by their names.

# %%
# Practicing order by to sort result follow condition preference
# %%sql
select name
from nyc_subway_stations order by name asc;
# Out:
#                    NAME
# 0              103rd St
# 1              103rd St
# 2              103rd St
# 3              103rd St
# 4              104th St
# ..                  ...
# 486            Woodlawn
# 487  World Trade Center
# 488         Wyckoff Ave
# 489             York St
# 490          Zerega Ave
#
# [491 rows x 1 columns]

# %% [markdown]
# ## Question 5: Unique Values
#
# Write a SQL query to find the distinct boroughs represented in the `nyc_subway_stations` dataset.

# %%
# Filter by select distinct values as different bouroughs
# %%sql
select distinct borough
from nyc_subway_stations;
# Out:
#          BOROUGH
# 0       Brooklyn
# 1         Queens
# 2      Manhattan
# 3          Bronx
# 4  Staten Island

# %% [markdown]
# ## Question 6: Counting Rows
#
# Write a SQL query to count the number of subway stations in each borough in the `nyc_subway_stations` dataset.

# %%
# Couting distinct id of subway stations in each borough
# %%sql
select count(distinct id)
from nyc_subway_stations
group by borough;
# Out:
#    count(DISTINCT id)
# 0                 170
# 1                  90
# 2                 140
# 3                  69
# 4                  22

# %%
# %%sql
# select borough, count(distinct id)
# from nyc_subway_stations
# group by borough;
# Out:
#          BOROUGH  count(DISTINCT id)
# 0       Brooklyn                 170
# 1         Queens                  90
# 2      Manhattan                 140
# 3          Bronx                  69
# 4  Staten Island                  22

# %% [markdown]
# ## Question 7: Aggregating Data
#
# Write a SQL query to list the number of subway stations in each borough, sorted in descending order by the count.

# %%
# Couting distinct id of subway stations in each borough and descending order by the count
# %%sql
select borough, count(distinct id)
from nyc_subway_stations
group by borough
order by count(distinct id)desc;
# Out:
#          BOROUGH  count(DISTINCT id)
# 0       Brooklyn                 170
# 1      Manhattan                 140
# 2         Queens                  90
# 3          Bronx                  69
# 4  Staten Island                  22

# %% [markdown]
# ## Question 8: Joining Tables
#
# Write a SQL query to join the `nyc_subway_stations` and `nyc_neighborhoods` datasets on the borough name, displaying the subway station name and the neighborhood name.

# %%
# Practice to join tables
# %%sql
select nyc_subway_stations.name,
       nyc_neighborhoods.name
from nyc_subway_stations
join nyc_neighborhoods
on nyc_subway_stations.borough = nyc_neighborhoods.boroname;
# Out:
#                     NAME      NAME_1
# 0           Cortlandt St   Chinatown
# 1              Rector St   Chinatown
# 2            South Ferry   Chinatown
# 3               W 4th St   Chinatown
# 4                15th St    Red Hook
# ...                  ...         ...
# 11053     JFK Terminal 8  Auburndale
# 11054     Federal Circle  Auburndale
# 11055  Long Term Parking  Auburndale
# 11056       Howard Beach  Auburndale
# 11057            Jamaica  Auburndale
#
# [11058 rows x 2 columns]

# %%
# %%sql
# SELECT
#   nyc_subway_stations.name AS station_name,
#   nyc_neighborhoods.name AS neighborhood_name
# FROM nyc_subway_stations
# JOIN nyc_neighborhoods
#   ON nyc_subway_stations.borough = nyc_neighborhoods.boroname;
# Out:
#             station_name neighborhood_name
# 0           Cortlandt St         Chinatown
# 1              Rector St         Chinatown
# 2            South Ferry         Chinatown
# 3               W 4th St         Chinatown
# 4                15th St          Red Hook
# ...                  ...               ...
# 11053     JFK Terminal 8        Auburndale
# 11054     Federal Circle        Auburndale
# 11055  Long Term Parking        Auburndale
# 11056       Howard Beach        Auburndale
# 11057            Jamaica        Auburndale
#
# [11058 rows x 2 columns]

# %% [markdown]
# ## Question 9: String Manipulation
#
# Write a SQL query to display the names of subway stations in the `nyc_subway_stations` dataset that contain the word "St" in their names.

# %%
# %%sql
# SELECT name
# FROM nyc_subway_stations
# WHERE name LIKE '%St%';
# Out:
#               NAME
# 0     Cortlandt St
# 1        Rector St
# 2         138th St
# 3         149th St
# 4         149th St
# ..             ...
# 225  Beach 98th St
# 226        Main St
# 227    Steinway St
# 228      St George
# 229      Stapleton
#
# [230 rows x 1 columns]

# %% [markdown]
# ## Question 10: Filtering with Multiple Conditions
#
# Write a SQL query to find all subway stations in the `nyc_subway_stations` dataset that are in the borough of Brooklyn and have routes that include the letter "R".

# %%
# %%sql
# select name
# from nyc_subway_stations
# where borough = 'Brooklyn' and routes like '%R%';
# Out:
#              NAME
# 0         25th St
# 1         36th St
# 2         45th St
# 3         53rd St
# 4         59th St
# 5         77th St
# 6         86th St
# 7         95th St
# 8          9th St
# 9   Bay Ridge Ave
# 10       Court St
# 11     DeKalb Ave
# 12    Lawrence St
# 13     Pacific St
# 14   Prospect Ave
# 15       Union St

# %% [markdown]
# Once you've completed your attempt, you can check your answers [here](https://github.com/oballinger/CASA0025/blob/main/notebooks/W02_lab_solution.ipynb).
